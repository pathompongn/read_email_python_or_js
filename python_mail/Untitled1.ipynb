# %%
# %run Test_Pandas/test_pandas.py
# Out:
#                                                 Label  # Samples  Average  \
# 0                   1.01 https://hrlos.dev.krungthai/         20       91
# 1                                     SC1_01_Open_web         20       91
# 2   2.01 https://hrlosws.dev.krungthai/hrlos-authe...         20       41
# 3   2.02 https://hrlosws.dev.krungthai/hrlos-authe...         20       19
# 4                                       SC1_02_Log_on         20       60
# 5   3.01 https://hrlosws.dev.krungthai/hrlos-authe...         20       37
# 6   3.02 https://hrlosws.dev.krungthai/hrlos-authe...         20       24
# 7   3.03 https://hrlosws.dev.krungthai/hrlos-appli...         20      219
# 8                       SC1_03_Select_Role>Click ตกลง         20      281
# 9   4.01 https://hrlosws.dev.krungthai/hrlos-maste...         20       16
# 10                           SC1_04_Click_สร้างใบคำขอ         20       16
# 11  5.01 https://hrlosws.dev.krungthai/hrlos-appli...         20     1241
# ...
